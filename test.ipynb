# %%
import numpy as np
import matplotlib.pyplot as plt
# round(list(np.random.normal(-2, 10**0.5, 1))[0],0)
y=np.random.normal(-2, 10**0.5, 1000)
plt.hist(y,100,density=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [11], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 # round(list(np.random.normal(-2, 10**0.5, 1))[0],0)
#       4 y=np.random.normal(-2, 10**0.5, 1000)
#
# File e:\python\lib\site-packages\matplotlib\pyplot.py:52
#      50 from cycler import cycler
#      51 import matplotlib
# ---> 52 import matplotlib.colorbar
#      53 import matplotlib.image
#      54 from matplotlib import _api
#
# File e:\python\lib\site-packages\matplotlib\colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File e:\python\lib\site-packages\matplotlib\collections.py:20
#      17 import numpy as np
#      19 import matplotlib as mpl
# ---> 20 from . import (_api, _path, artist, cbook, cm, colors as mcolors, _docstring,
#      21                hatch as mhatch, lines as mlines, path as mpath, transforms)
#      22 from ._enums import JoinStyle, CapStyle
#      25 # "color" is excluded; it is a compound setter, and its docstring differs
#      26 # in LineCollection.
#
# File e:\python\lib\site-packages\matplotlib\lines.py:14
#      12 import matplotlib as mpl
#      13 from . import _api, cbook, colors as mcolors, _docstring
# ---> 14 from .artist import Artist, allow_rasterization
#      15 from .cbook import (
#      16     _to_unmasked_float_array, ls_mapper, ls_mapper_r, STEP_LOOKUP_MAP)
#      17 from .markers import MarkerStyle
#
# ModuleNotFoundError: No module named 'matplotlib.artist'

# %%
import numpy as np
from scipy.stats import beta
from scipy.stats import cauchy
import matplotlib.pyplot as plt
# round(list(np.random.normal(2, 10, 1))[0],1)
y=np.random.normal(-2,10**0.5,10000)
plt.hist(y,100,density=True)
plt.legend(['Gauss'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [10], line 4
#       2 from scipy.stats import beta
#       3 from scipy.stats import cauchy
# ----> 4 import matplotlib.pyplot as plt
#       5 # round(list(np.random.normal(2, 10, 1))[0],1)
#       6 y=np.random.normal(-2,10**0.5,10000)
#
# File e:\python\lib\site-packages\matplotlib\pyplot.py:52
#      50 from cycler import cycler
#      51 import matplotlib
# ---> 52 import matplotlib.colorbar
#      53 import matplotlib.image
#      54 from matplotlib import _api
#
# File e:\python\lib\site-packages\matplotlib\colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File e:\python\lib\site-packages\matplotlib\collections.py:20
#      17 import numpy as np
#      19 import matplotlib as mpl
# ---> 20 from . import (_api, _path, artist, cbook, cm, colors as mcolors, _docstring,
#      21                hatch as mhatch, lines as mlines, path as mpath, transforms)
#      22 from ._enums import JoinStyle, CapStyle
#      25 # "color" is excluded; it is a compound setter, and its docstring differs
#      26 # in LineCollection.
#
# File e:\python\lib\site-packages\matplotlib\lines.py:14
#      12 import matplotlib as mpl
#      13 from . import _api, cbook, colors as mcolors, _docstring
# ---> 14 from .artist import Artist, allow_rasterization
#      15 from .cbook import (
#      16     _to_unmasked_float_array, ls_mapper, ls_mapper_r, STEP_LOOKUP_MAP)
#      17 from .markers import MarkerStyle
#
# ModuleNotFoundError: No module named 'matplotlib.artist'

# %%
np.mean(y),np.var(y)
# Out:
# (-1.9833882059988046, 9.76685181564542)

# %%
a=0.5
b=0.5
x=np.arange(0.01,1,0.01)
y=beta.pdf(x,a,b)
plt.plot(x,y)
plt.title('Beta')
plt.xlabel('x')
plt.ylabel('density')
plt.show()

# %%
#需要导入的库
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as sps

shape,scale=2.,2.
s=np.random.gamma(shape,scale,1000)
count, bins, ignored = plt.hist(s, 50)#50：是50个条形图
'''
根据伽马分布的概率密度
伽马分布常被用来模拟电子元件的失效时间，
并且在泊松分布事件之间的等待时间相关的过程中自然产生。
'''
y=bins**(shape-1)*(np.exp(-bins/scale)/(sps.gamma(shape)*scale**shape))
plt.title('gamma')
plt.plot(bins,y,linewidth=2,color='r')
plt.show()

# %%
cnt=100 #抽样1000个样本点
x=np.random.standard_cauchy(2)
print(x)
y=np.random.randn(cnt)

plt.figure()
plt.subplot(3,1,1)
plt.hist(x,100,density=True)
plt.legend(['normal Cauchy'])

plt.subplot(3,1,2)
plt.hist(y,100,density=True)
plt.legend(['Gauss'])
plt.show()
# Out:
# [0.2005352  1.03754156]

# %%
import numpy as np 
import matplotlib.pyplot as plt 

rv=cauchy()
distribution = np.linspace(0, np.minimum(rv.dist.b, 5)) 
print("Distribution : \n", distribution) 
  
plot = plt.plot(distribution, rv.pdf(distribution))
# Out:
# Distribution :
#  [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
from scipy.stats import poisson
# import seaborn as sb

data_binom = poisson.rvs(mu=8, size=10000)
plt.figure()
plt.subplot(2,1,1)
plt.hist(data_binom,100,density=True)
plt.legend(['poisson'])
plt.show()

# %%
data_binom.sum(),np.mean(data_binom)
# Out:
# (99916, 9.9916)

# %%
import math
 
def p_possion(k, m):
    kjie = 1  #k!
    for i in range(1, k+1):
        kjie*=i
    pk = math.pow(m, k)/kjie*math.e**(-m)
    return pk
 
p = p_possion(15, 20)
print("接到15个骚扰电话的概率：",p)
 
p=0
for i in range(0,25):
    p+=p_possion(i, 20)
print("接到24个骚扰电话以下的概率：",p)
# Out:
# 接到15个骚扰电话的概率： 0.0516488535317584
# 接到24个骚扰电话以下的概率： 0.8432273781737633

# %%
from scipy import stats
 
p = stats.poisson.pmf(15, 20)
print("接到15个骚扰电话的概率：",p)
 
p = stats.poisson.cdf(24, 20)
print("接到24个骚扰电话以下的概率：",p)
# Out:
# 接到15个骚扰电话的概率： 0.05164885353175814
# 接到24个骚扰电话以下的概率： 0.8432273781737623
