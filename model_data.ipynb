# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"model_data1124.csv")
data
# Out:
#      bomb             datetime  act_deal  con_deal  \
# 0       0  2019-01-02 00:00:00     806.0       0.0
# 1       0  2019-01-03 00:00:00     567.0       0.0
# 2       0  2019-01-04 00:00:00     460.0       0.0
# 3       0  2019-01-07 00:00:00     352.0       0.0
# 4       0  2019-01-08 00:00:00     302.0       0.0
# ..    ...                  ...       ...       ...
# 927     0  2022-10-31 00:00:00       3.0      11.0
# 928     0  2022-11-01 00:00:00      47.0     328.0
# 929     0  2022-11-02 00:00:00      30.0     249.0
# 930     0  2022-11-03 00:00:00      23.0     138.0
# 931     0  2022-11-04 00:00:00      21.0     112.0
#
#                                              act_table  \
# 0    [     long  price  agent\n0     0.0  417.0  21...
# 1    [     long  price  agent\n0     0.0  408.0  28...
# 2    [     long  price  agent\n0     0.0  423.9  39...
# 3    [     long  price  agent\n0     0.0  437.8  29...
# 4    [     long  price  agent\n0     0.0  448.2  35...
# ...

# %%
price_list=pd.read_csv(r"data.csv")
price_list
# Out:
#                     date  act_closing  con_closing  act_settlement  \
# 0    2018-12-28 00:00:00        379.1        342.0           377.9
# 1    2019-01-02 00:00:00        370.9        367.5           374.6
# 2    2019-01-03 00:00:00        385.4        379.8           384.3
# 3    2019-01-04 00:00:00        398.0        393.5           393.9
# 4    2019-01-07 00:00:00        407.5        404.8           405.9
# ..                   ...          ...          ...             ...
# 928  2022-10-31 00:00:00        679.8        680.0           683.5
# 929  2022-11-01 00:00:00        692.4        692.4           684.7
# 930  2022-11-02 00:00:00        698.5        698.5           696.0
# 931  2022-11-03 00:00:00        701.8        701.8           696.5
# 932  2022-11-04 00:00:00        710.5        710.5           700.0
#
#      con_settlement  turnover  transaction  inventory  act_invent  con_invent
# 0             380.1  491082.0  18562262.36    59774.0     43220.0      5026.0
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,12))
plt.plot(data['bomb'].values.tolist())
# plt.plot(data['act_deal'].values.tolist())
# plt.plot(data['bomb'].values.tolist())
plt.show()

# %%
plt.figure(figsize=(16,12))
# plt.plot(data['bomb'].values.tolist())
plt.plot(data['act_deal'].values.tolist())
plt.plot(price_list['con_settlement'].values.tolist())
plt.show()
